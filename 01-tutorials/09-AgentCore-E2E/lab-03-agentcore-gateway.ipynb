# %% [markdown]
# # Lab 3: Securely connect tools to your Agent with AgentCore Gateway
#
# ## Overview
#
# In this Lab, you will learn how to integrate tools available in your organization with the Customer Support Agent using the Amazon Bedrock Gateway.
#
# The [Model Context Protocol (MCP)](https://modelcontextprotocol.io/docs/getting-started/intro) is an open protocol that standardizes how applications provide tools and context to Large Language Models (LLMs).
#
# With [Amazon Bedrock Agent Core Gateway](https://docs.aws.amazon.com/bedrock-agentcore/latest/devguide/gateway.html), developers can convert APIs, Lambda functions, and existing services into MCP-compatible tools and make them available to agents through Gateway endpoints with just a few lines of code.
#
#
# **Workshop Journey:**
#
# - **Lab 1 (Done):** Create Agent Prototype - Built a functional customer support agent
# - **Lab 2 (Done):** Enhance with Memory - Added conversation context and personalization
# - **Lab 3 (Current):** Scale with Gateway & Identity - Shared tools across agents securely
# - **Lab 4:** Deploy to Production - Used AgentCore Runtime with observability
# - **Lab 5:** Evaluate Agent Performance - Monitor quality with online evaluations
# - **Lab 6:** Build User Interface - Create a customer-facing application
#
#
# ### Why AgentCore Gateway & Tool Sharing Matter
#
# Current State (Lab 1-2): Each agent has its own copy of tools. A practice that is not scalable and leads to:
#
# - Code duplication across different agents
# - Inconsistent tool behavior and maintenance overhead
# - No centralized security or access control
# - Difficulty scaling to multiple use cases
#
# After this lab, we will have centralized, reusable tools that can serve:
#
# - Customer Support Agent (our current use case)
# - Sales Agent (needs same product info and customer data)
# - Inventory Agent (needs same product info and warranty checking)
# - Returns Processing Agent (needs return policies and customer profiles)
#
# and other use cases.
#
# ### Adding secure authentication with AgentCore Identity
#
# Additionally, AgentCore Gateway requires you to securely authenticate both inbound and outbound connections. [AgentCore Identity](https://docs.aws.amazon.com/bedrock-agentcore/latest/devguide/identity.html) provides seamless agent identity and access management across AWS services and third-party applications such as Slack and Zoom while supporting any standard identity providers such as Okta, Entra, and Amazon Cognito. In this lab we will see how AgentCore Gateway integrates with AgentCore Identity to provide secure connections via inbound and outbound authentication.
#
# For the inbound authentication, the AgentCore Gateway analyzes the OAuth token passed during invocation to decide allow or deny the access to a tool in the gateway. If a tool needs access to external resources, the AgentCore Gateway can use outbound authentication via API Key, IAM or OAuth Token to allow or deny the access to the external resource.
#
# During the inbound authorization flow, an agent or the MCP client calls an MCP tool in the AgentCore Gateway adding an OAuth access token (generated from the user’s IdP). AgentCore Gateway then validates the OAuth access token and performs inbound authorization.
#
# If the tool running in AgentCore Gateway needs to access external resources, OAuth will retrieve credentials of downstream resources using the resource credential provider for the Gateway target. AgentCore Gateway pass the authorization credentials to the caller to get access to the downstream API.
#
#
# ## Architecture for Lab 3
#
# <div style="text-align:left">
#     <img src="images/architecture_lab3_gateway.png" width="75%"/>
# </div>
#
# *Web search tool is now centralized in AgentCore Gateway with secure identity-based access control. Multiple agents and use cases can share the same tool securely. We will also reuse the `check_warranty()` tool built for other applications and add the `web_search()` tool for use within other applications. `get_product_info()`, `get_return_policy()`, and `get_technical_support` remain as local tools as they are specific to the customer support use case*
#
# ### Key Features
# - **Seamlessly integrate AWS Lambda functions:** This example shows how to integrate your Agent with existing AWS Lambda functions to check the warranty of an item and to get the customer profile using Amazon Bedrock AgentCore Gateway.
# - **Secure your Gateway endpoint with Inbound Auth**: Only an Agent providing a valid JWT token can connect to the endpoint to use the tools
# - **Configure the Agent to use the MCP endpoint**: The Agent gets a valid JWT token and uses it to connect to the MCP endpoint provided by AgentCore Gateway
#
# ## Prerequisites
#
# * Python 3.12+
# * AWS credentials configured
# * Anthropic Claude 3.7 enabled on [Amazon Bedrock](https://docs.aws.amazon.com/bedrock/latest/userguide/model-access.html)
# * Complete Lab 2 Add memory to the Customer Support Agent
# * These resources are created for you within an AWS workshop account
#     - AWS Lambda function
#     - AWS Lambda Execution IAM Role
#     - AgentCore Gateway IAM Role
#     - DynamoDB tables used by the AWS Lambda function.
#     - Cognito User Pool and User Pool Client

# %% [markdown]
# ## Step 1: Import required libraries

# %%
import os
from dotenv import load_dotenv
load_dotenv(dotenv_path=".env", override=True)
print(os.environ["AWS_PROFILE"])
print(os.environ["AWS_REGION"])
# Out:
# personal
# us-east-1

# %%
# Import libraries
import os
import sys
import boto3

from strands import Agent
from strands.models import BedrockModel
from strands.tools.mcp import MCPClient
from mcp.client.streamable_http import streamablehttp_client
from lab_helpers.utils import (
    get_or_create_cognito_pool,
    put_ssm_parameter,
    get_ssm_parameter,
    load_api_spec,
)


sts_client = boto3.client("sts")

# Get AWS account details
REGION = boto3.session.Session().region_name

gateway_client = boto3.client(
    "bedrock-agentcore-control",
    region_name=REGION,
)

print("✅ Libraries imported successfully!")
# Out:
# ✅ Libraries imported successfully!

# %% [markdown]
# ## Step 2: Give our agent a tool to access existing customer data
# AgentCore Gateway simplifies agent tool integration in three key ways:
#
# - Universal MCP Support: Instantly make your tools compatible with any agent framework by exposing them through AgentCore Gateway's MCP standard
#
# - Simple REST Integration: Transform existing REST services into agent tools by just adding them as AgentCore Gateway targets
#
# - Lambda Flexibility: Expose Lambda functions as MCP endpoints that can call any API - demonstrated here with a function that checks warranty status
#
# AgentCore Gateway populates the Lambda context with the name of the tool to invoke, while the parameters passed to the tool are provided in the Lambda event:
#
# ```
# extended_tool_name = context.client_context.custom["bedrockAgentCoreToolName"]
# resource = extended_tool_name.split("___")[1]
# ```
#
# [Lambda function](./prerequisite/lambda/python/lambda_function.py)
#
# ```
# def lambda_handler(event, context):
#     if get_tool_name(event) == "check_warranty_status":
#         serial_number = get_named_parameter(event=event, name="serial_number")
#         customer_email = get_named_parameter(event=event, name="customer_email")
#
#         warranty_status = check_warranty_status(serial_number, customer_email)
#         return {"statusCode": 200, "body": warranty_status}
# ```

# %% [markdown]
# ## Step 3 Convert your web search tool to MCP
# Now that we are developing an MCP server using AgentCore Gateway, we can MCP-ify any tools which we think we'll use for multiple Agents. One of these tools might be a web search tool like we built in Lab1. As a result, we also converted the web search tool from Lab 1 into a Lambda tool within our AgentCore Gateway:
#
# [Web search Lambda](./prerequisite/lambda/python/web_search.py)
# ```
# from ddgs import DDGS
#
#
# def web_search(keywords: str, region: str = "us-en", max_results: int = 5) -> str:
#     """Search the web for updated information.
#
#     Args:
#         keywords (str): The search query keywords.
#         region (str): The search region: wt-wt, us-en, uk-en, ru-ru, etc.
#         max_results (int): The maximum number of results to return.
#
#     Returns:
#         List of dictionaries with search results.
#     """
#     try:
#         results = DDGS().text(keywords, region=region, max_results=max_results)
#         return results if results else "No results found."
#     except Exception as e:
#         return f"Search error: {str(e)}"
#
#
# print("✅ Web search tool ready")
# ```

# %% [markdown]
# ## Step 4 Create your function definition metadata
# Lastly, we need to write tool schema which describes the tools implemented by your Lambda function.
#
# This file has been already defined in [prerequisite/lambda/api_spec.json](./prerequisite/lambda/api_spec.json)
#
# ```
# [
#     {
#         "name": "check_warranty_status",
#         "description": "Check the warranty status of a product using its serial number and optionally verify via email",
#         "inputSchema": {
#             "type": "object",
#             "properties": {
#                 "serial_number": {
#                     "type": "string"
#                 },
#                 "customer_email": {
#                     "type": "string"
#                 }
#             },
#             "required": [
#                 "serial_number"
#             ]
#         }
#     },
#     {
#         "name": "web_search",
#         "description": "Search the web for updated information using DuckDuckGo",
#         "inputSchema": {
#             "type": "object",
#             "properties": {
#                 "keywords": {
#                     "type": "string",
#                     "description": "The search query keywords"
#                 },
#                 "region": {
#                     "type": "string",
#                     "description": "The search region (e.g., us-en, uk-en, ru-ru)"
#                 },
#                 "max_results": {
#                     "type": "integer",
#                     "description": "The maximum number of results to return"
#                 }
#             },
#             "required": [
#                 "keywords"
#             ]
#         }
#     }
# ]
# ```

# %% [markdown]
# ## Step 5. Create your AgentCore Gateway
#
# Now let's create the AgentCore Gateway to expose the Lambda function as MCP-compatible endpoint.
#
# To validate the callers authorized to invoke our tools we need to configure the Inbound Auth.
#
# Inbound Auth works using OAuth authorization, the standard for MCP servers. With OAuth the client application must authenticate with the OAuth authorizer before using the Gateway. Your client would receive an access token which is used at runtime.
#
# You need to specify an OAuth discovery server and client IDs. The Cloudformation provided with the workshop already provisioned the Cognito UserPool and UserPoolClient and it stored the discovery URL and the Client ID in dedicated SSM parameters.

# %%
# COGNITO
gateway_name = "customersupport-gw"

cognito_config = get_or_create_cognito_pool(refresh_token=True)
auth_config = {
    "customJWTAuthorizer": {
        "allowedClients": [cognito_config["client_id"]],
        "discoveryUrl": cognito_config["discovery_url"],
    }
}

# %%
print(f"Creating gateway in region {REGION} with name: {gateway_name}")
# Out:
# Creating gateway in region us-east-1 with name: customersupport-gw

# %%
get_ssm_parameter("/app/customersupport/agentcore/gateway_iam_role")
# Out:
# 'arn:aws:iam::801195563340:role/CustomerSupportStackInfra-GatewayAgentCoreRole-2zQesBrdrXN9'

# %%
# CREATE A GATEWAY
create_response = gateway_client.create_gateway(
        name=gateway_name,
        roleArn=get_ssm_parameter("/app/customersupport/agentcore/gateway_iam_role"),
        protocolType="MCP",
        authorizerType="CUSTOM_JWT",
        authorizerConfiguration=auth_config,
        description="Customer Support AgentCore Gateway",
    )

# %%
gateway_id = create_response["gatewayId"]

gateway = {
    "id": gateway_id,
    "name": gateway_name,
    "gateway_url": create_response["gatewayUrl"],
    "gateway_arn": create_response["gatewayArn"],
}

# %%
gateway
# Out:
# {'id': 'customersupport-gw-rptkpcmbxg',
#  'name': 'customersupport-gw',
#  'gateway_url': 'https://customersupport-gw-rptkpcmbxg.gateway.bedrock-agentcore.us-east-1.amazonaws.com/mcp',
#  'gateway_arn': 'arn:aws:bedrock-agentcore:us-east-1:801195563340:gateway/customersupport-gw-rptkpcmbxg'}

# %%
put_ssm_parameter("/app/customersupport/agentcore/gateway_id", gateway_id)
put_ssm_parameter("/app/customersupport/agentcore/gateway_name", gateway_name)
put_ssm_parameter(
    "/app/customersupport/agentcore/gateway_arn", create_response["gatewayArn"]
)
put_ssm_parameter(
    "/app/customersupport/agentcore/gateway_url", create_response["gatewayUrl"]
)

# %%
print(f"✅ Gateway created successfully with ID: {gateway_id}")
# Out:
# ✅ Gateway created successfully with ID: customersupport-gw-rptkpcmbxg

# %%
# If gateway exists, collect existing gateway ID from SSM
existing_gateway_id = get_ssm_parameter("/app/customersupport/agentcore/gateway_id")
print(f"Found existing gateway with ID: {existing_gateway_id}")

# Get existing gateway details
gateway_response = gateway_client.get_gateway(gatewayIdentifier=existing_gateway_id)
gateway = {
    "id": existing_gateway_id,
    "name": gateway_response["name"],
    "gateway_url": gateway_response["gatewayUrl"],
    "gateway_arn": gateway_response["gatewayArn"],
}
gateway_id = gateway["id"]
# Out:
# Found existing gateway with ID: customersupport-gw-rptkpcmbxg

# %%
gateway
# Out:
# {'id': 'customersupport-gw-rptkpcmbxg',
#  'name': 'customersupport-gw',
#  'gateway_url': 'https://customersupport-gw-rptkpcmbxg.gateway.bedrock-agentcore.us-east-1.amazonaws.com/mcp',
#  'gateway_arn': 'arn:aws:bedrock-agentcore:us-east-1:801195563340:gateway/customersupport-gw-rptkpcmbxg'}

# %% [markdown]
# ## Step 6. Add the Lambda function Target
# Now we will use the previously defined function definitions from [prerequisite/lambda/api_spec.json](./prerequisite/lambda/api_spec.json) to create a Lambda target within our Agent Gateway. This will define the tools that your gateway will host.
#
# Gateway allows you to attach multiple targets to a Gateway and you can change the targets / tools attached to a gateway at any point. Each target can have its own credential provider, but Gateway becomes a single MCP URL enabling access to all of the relevant tools for an agent across myriad APIs.

# %%
api_spec_file = "./prerequisite/lambda/api_spec.json"
os.path.exists(api_spec_file)
api_spec = load_api_spec(api_spec_file)
api_spec
# Out:
# [{'name': 'check_warranty_status',
#   'description': 'Check the warranty status of a product using its serial number and optionally verify via email',
#   'inputSchema': {'type': 'object',
#    'properties': {'serial_number': {'type': 'string'},
#     'customer_email': {'type': 'string'}},
#    'required': ['serial_number']}},
#  {'name': 'web_search',
#   'description': 'Search the web for updated information using DuckDuckGo',
#   'inputSchema': {'type': 'object',
#    'properties': {'keywords': {'type': 'string',
#      'description': 'The search query keywords'},
#     'region': {'type': 'string',
#      'description': 'The search region (e.g., us-en, uk-en, ru-ru)'},
#     'max_results': {'type': 'integer',
#      'description': 'The maximum number of results to return'}},
#    'required': ['keywords']}}]

# %%
lambda_target_config = {
    "mcp": {
        "lambda": {
            "lambdaArn": get_ssm_parameter(
                "/app/customersupport/agentcore/lambda_arn"
            ),
            "toolSchema": {"inlinePayload": api_spec},
        }
    }
}

# %%
# Create gateway target
credential_config = [{"credentialProviderType": "GATEWAY_IAM_ROLE"}]

create_target_response = gateway_client.create_gateway_target(
    gatewayIdentifier=gateway_id,
    name="LambdaUsingSDK",
    description="Lambda Target using SDK",
    targetConfiguration=lambda_target_config,
    credentialProviderConfigurations=credential_config,
)

# %%
print(f"✅ Gateway target created: {create_target_response['targetId']}")
# Out:
# ✅ Gateway target created: OYBNZOJTVH

# %% [markdown]
# ## Step 7: Add our new MCP-based tools to our support agent
# Here we integrate our authentication token from Cognito into an MCPClient from Strands SDK to create an MCP Server object to integrate with our Strands Agent
# ### Step 7.1. Set up a secure MCP client object

# %%
print(f"Gateway Endpoint - MCP URL: {gateway['gateway_url']}")
# Set up MCP client
mcp_client = MCPClient(
    lambda: streamablehttp_client(
        gateway["gateway_url"],
        headers={"Authorization": f"Bearer {cognito_config['bearer_token']}"},
    )
)
# Out:
# Gateway Endpoint - MCP URL: https://customersupport-gw-rptkpcmbxg.gateway.bedrock-agentcore.us-east-1.amazonaws.com/mcp

# %%
# cognito_config['bearer_token']

# %%
# mcp_client.list_tools_sync(pagination_token=None)

# %% [markdown]
# ## Step 7.2. Access tools in our agent using our MCP client
# Now we will create our Strands Agent using the AgentCore Gateway we built along with the resources from previous labs. Our agent now uses a mix of local tools via our Strands Agent and MCP tools via AgentCore Gateway

# %%
from lab_helpers.lab1_strands_agent import (
    get_product_info,
    get_return_policy,
    get_technical_support,
    SYSTEM_PROMPT,
)

import uuid
from lab_helpers.lab2_memory import create_or_get_memory_resource
from bedrock_agentcore.memory.integrations.strands.config import AgentCoreMemoryConfig, RetrievalConfig
from bedrock_agentcore.memory.integrations.strands.session_manager import AgentCoreMemorySessionManager

# %%
with mcp_client:
    tools = mcp_client.list_tools_sync()

# %%
mcp_tool = tools[0].mcp_tool
mcp_tool
# Out:
# Tool(name='LambdaUsingSDK___check_warranty_status', title=None, description='Check the warranty status of a product using its serial number and optionally verify via email', inputSchema={'type': 'object', 'properties': {'customer_email': {'type': 'string'}, 'serial_number': {'type': 'string'}}, 'required': ['serial_number']}, outputSchema=None, icons=None, annotations=None, meta=None, execution=None)

# %%
mcp_tool.inputSchema
# Out:
# {'type': 'object',
#  'properties': {'customer_email': {'type': 'string'},
#   'serial_number': {'type': 'string'}},
#  'required': ['serial_number']}

# %%
# MEMORY
memory_id = create_or_get_memory_resource()

SESSION_ID = str(uuid.uuid4())
CUSTOMER_ID = "customer_001"

memory_config = AgentCoreMemoryConfig(
        memory_id=memory_id,
        session_id=str(SESSION_ID),
        actor_id=CUSTOMER_ID,
        retrieval_config={
            "support/customer/{actorId}/semantic": RetrievalConfig(top_k=3, relevance_score=0.2),
            "support/customer/{actorId}/preferences": RetrievalConfig(top_k=3, relevance_score=0.2)
        }
    )

# %%
# Initialize the Bedrock model
model_id = "global.anthropic.claude-haiku-4-5-20251001-v1:0"
model = BedrockModel(
    model_id=model_id,
    temperature=0.3,  # Balanced between creativity and consistency
    region_name=REGION,
)

# %%
def create_agent(prompt):
    try:
        with mcp_client:
            tools = [
                get_product_info,
                get_return_policy,
                get_technical_support,
            ] + mcp_client.list_tools_sync()

            # Create the customer support agent
            agent = Agent(
                model=model,
                tools=tools,
                system_prompt=SYSTEM_PROMPT,
                session_manager=AgentCoreMemorySessionManager(memory_config, REGION),
            )
            response = agent(prompt)
            return response
    except Exception as e:
        raise e


print("✅ Customer support agent created successfully!")
# Out:
# ✅ Customer support agent created successfully!

# %% [markdown]
# ## Step 8: Test the agent with MCP tool access to existing APIs”
#
# Let's test our agent with sample queries to ensure all features work correctly. You should see 5 tools in the output.

# %%
test_prompts = [
    # Warranty Checks
    "List all of your tools",
    "I bought an iphone 14 last month. I don't like it because it heats up. How do I solve it?",
    "I have a Gaming Console Pro device , I want to check my warranty status, warranty serial number is MNO33333333.",
    "What are the warranty support guidelines?",
    "How can I fix Lenovo Thinkpad with a blue screen",
    "Tell me detailed information about the technical documentation on installing a new CPU",
]

# %%
with mcp_client:
    tools = [
        get_product_info,
        get_return_policy,
        get_technical_support,
    ] + mcp_client.list_tools_sync()

# %%
for i, prompt in enumerate(test_prompts, 1):
    break

# %%
print(i, prompt)
agent = Agent(
    model=model,
    tools=tools,
    system_prompt=SYSTEM_PROMPT,
    session_manager=AgentCoreMemorySessionManager(memory_config, REGION),
)
# Out:
# 1 List all of your tools

# %%
response = agent(prompt)
# Out:
# Here are all the tools available to me as a customer support assistant:
#
# 1. **get_product_info(product_type)**
#    - Gets detailed technical specifications and information for electronics products
#    - Returns: Formatted product information including warranty, features, and policies
#    - Parameters: `product_type` (e.g., 'laptops', 'smartphones', 'headphones', 'monitors')
#
# 2. **get_return_policy(product_category)**
#    - Gets return policy information for a specific product category
#    - Returns: Formatted return policy details including timeframes and conditions
#    - Parameters: `product_category` (e.g., 'smartphones', 'laptops', 'accessories')
#
# 3. **get_technical_support(issue_description)**
#    - Provides technical support for product issues
#    - Returns: Technical support guidance and solutions
#    - Parameters: `issue_description` (description of the technical issue)
#
# 4. **LambdaUsingSDK___check_warranty_status(serial_number, customer_email)**
#    - Checks the warranty status of a product using its serial number
#    - Returns: Warranty status information
#    - Parameters: `serial_number` (required), `customer_email` (optional)
#
# 5. **LambdaUsingSDK___web_search(keywords, max_results, region)**
#    - Searches the web for updated information using DuckDuckGo
#    - Returns: Search results with current information
#    - Parameters: `keywords` (required), `max_results` (optional), `region` (optional, e.g., 'us-en', 'uk-en')
#
# ---
#
# Is there anything specific I can help you with today? Whether it's product information, technical support, warranty questions, or return policies, I'm here to assist!

# %%
test_prompts = [
    # Warranty Checks
    "List all of your tools",
    "I bought an iphone 14 last month. I don't like it because it heats up. How do I solve it?",
    "I have a Gaming Console Pro device , I want to check my warranty status, warranty serial number is MNO33333333.",
    "What are the warranty support guidelines?",
    "How can I fix Lenovo Thinkpad with a blue screen",
    "Tell me detailed information about the technical documentation on installing a new CPU",
]


# Function to test the agent
def test_agent_responses(prompts):
    for i, prompt in enumerate(prompts, 1):
        print(f"\nTest Case {i}: {prompt}")
        print("-" * 50)
        try:
            response = create_agent(prompt)
            print(response)
        except Exception as e:
            print(f"Error: {str(e)}")
        print("-" * 50)


# Run the tests
test_agent_responses(test_prompts)

print("\\n✅ Basic testing completed!")
# Out:
# Test Case 1: List all of your tools
# --------------------------------------------------
#
#
# Here are all the tools available to me as a customer support assistant:
#
# 1. **get_product_info(product_type)**
#    - Gets detailed technical specifications and information for electronics products
#    - Returns: Formatted product information including warranty, features, and policies
#    - Parameters: `product_type` (e.g., 'laptops', 'smartphones', 'headphones', 'monitors')
#
# 2. **get_return_policy(product_category)**
#    - Gets return policy information for a specific product category
#    - Returns: Formatted return policy details including timeframes and conditions
#    - Parameters: `product_category` (e.g., 'smartphones', 'laptops', 'accessories')
#
# 3. **get_technical_support(issue_description)**
#    - Provides technical support for product issues
#    - Returns: Technical support guidance and solutions
#    - Parameters: `issue_description` (description of the technical issue)
#
# 4. **LambdaUsingSDK___check_warranty_status(serial_number, customer_email)**
#    - Checks the warranty status of a product using its serial number
#    - Returns: Warranty status information
#    - Parameters: `serial_number` (required), `customer_email` (optional)
#
# 5. **LambdaUsingSDK___web_search(keywords, max_results, region)**
#    - Searches the web for updated information using DuckDuckGo
#    - Returns: Search results with current information
#    - Parameters: `keywords` (required), `max_results` (optional), `region` (optional, e.g., 'us-en', 'uk-en')
#
# ---
#
# I notice from your profile that you're interested in gaming headphones with low latency for competitive FPS games and you have a MacBook Pro that's overheating during video editing. I'd be happy to help you with:
#
# - **Gaming headphones recommendations** with low-latency specifications
# - **Troubleshooting your MacBook Pro overheating issue** during video editing
# - **Product information and specifications** for any electronics
# - **Warranty and return policy questions**
#
# What can I assist you with today?
#
# Here are all the tools available to me as a customer support assistant:
#
# 1. **get_product_info(product_type)**
#    - Gets detailed technical specifications and information for electronics products
#    - Returns: Formatted product information including warranty, features, and policies
#    - Parameters: `product_type` (e.g., 'laptops', 'smartphones', 'headphones', 'monitors')
#
# 2. **get_return_policy(product_category)**
#    - Gets return policy information for a specific product category
#    - Returns: Formatted return policy details including timeframes and conditions
#    - Parameters: `product_category` (e.g., 'smartphones', 'laptops', 'accessories')
#
# 3. **get_technical_support(issue_description)**
#    - Provides technical support for product issues
#    - Returns: Technical support guidance and solutions
#    - Parameters: `issue_description` (description of the technical issue)
#
# 4. **LambdaUsingSDK___check_warranty_status(serial_number, customer_email)**
#    - Checks the warranty status of a product using its serial number
#    - Returns: Warranty status information
#    - Parameters: `serial_number` (required), `customer_email` (optional)
#
# 5. **LambdaUsingSDK___web_search(keywords, max_results, region)**
#    - Searches the web for updated information using DuckDuckGo
#    - Returns: Search results with current information
#    - Parameters: `keywords` (required), `max_results` (optional), `region` (optional, e.g., 'us-en', 'uk-en')
#
# ---
#
# I notice from your profile that you're interested in gaming headphones with low latency for competitive FPS games and you have a MacBook Pro that's overheating during video editing. I'd be happy to help you with:
#
# - **Gaming headphones recommendations** with low-latency specifications
# - **Troubleshooting your MacBook Pro overheating issue** during video editing
# - **Product information and specifications** for any electronics
# - **Warranty and return policy questions**
#
# What can I assist you with today?
#
# --------------------------------------------------
#
# Test Case 2: I bought an iphone 14 last month. I don't like it because it heats up. How do I solve it?
# --------------------------------------------------
#
#
# I'm sorry to hear your iPhone 14 is overheating! That's definitely frustrating. Let me help you troubleshoot this issue.
# Tool #1: get_technical_support
#
# Tool #2: get_return_policy
# Successfully retrieved KB ID: 9DN5FS1RMZ
# Great! I have some helpful information for you. Here are some steps to resolve the iPhone 14 overheating issue:
#
# ## **Troubleshooting Steps for iPhone 14 Overheating:**
#
# 1. **Battery Optimization**
#    - Enable battery optimization settings
#    - Adjust screen brightness and reduce timeout duration
#    - Manage background app refresh
#    - Configure location services to use "While Using" instead of "Always"
#    - Enable Low Power Mode when needed
#
# 2. **General Optimization**
#    - Close unnecessary apps running in the background
#    - Restart your iPhone (force restart if needed)
#    - Update to the latest iOS version
#    - Clear cache and temporary files
#
# 3. **Environmental Factors**
#    - Avoid direct sunlight exposure
#    - Remove any protective case temporarily to allow better heat dissipation
#    - Keep the device in a cool environment
#
# 4. **App Management**
#    - Check which apps are consuming the most battery/processing power
#    - Uninstall or update problematic apps
#    - Disable automatic app updates if they're causing excessive processing
#
# ## **Return/Replacement Option:**
#
# If the overheating persists after troubleshooting, here's our return policy for smartphones:
# - **Return window:** 30 days from delivery
# - **Condition:** Original packaging, no physical damage, factory reset required
# - **Refund timeline:** 5-7 business days after inspection
# - **Warranty:** 1-year manufacturer warranty included
#
# Since you purchased it last month, you should still be within the 30-day return window if you'd like to exchange it for a replacement.
#
# **Would you like me to help you with anything else, or do you need assistance with the return process?**Great! I have some helpful information for you. Here are some steps to resolve the iPhone 14 overheating issue:
#
# ## **Troubleshooting Steps for iPhone 14 Overheating:**
#
# 1. **Battery Optimization**
#    - Enable battery optimization settings
#    - Adjust screen brightness and reduce timeout duration
#    - Manage background app refresh
#    - Configure location services to use "While Using" instead of "Always"
#    - Enable Low Power Mode when needed
#
# 2. **General Optimization**
#    - Close unnecessary apps running in the background
#    - Restart your iPhone (force restart if needed)
#    - Update to the latest iOS version
#    - Clear cache and temporary files
#
# 3. **Environmental Factors**
#    - Avoid direct sunlight exposure
#    - Remove any protective case temporarily to allow better heat dissipation
#    - Keep the device in a cool environment
#
# 4. **App Management**
#    - Check which apps are consuming the most battery/processing power
#    - Uninstall or update problematic apps
#    - Disable automatic app updates if they're causing excessive processing
#
# ## **Return/Replacement Option:**
#
# If the overheating persists after troubleshooting, here's our return policy for smartphones:
# - **Return window:** 30 days from delivery
# - **Condition:** Original packaging, no physical damage, factory reset required
# - **Refund timeline:** 5-7 business days after inspection
# - **Warranty:** 1-year manufacturer warranty included
#
# Since you purchased it last month, you should still be within the 30-day return window if you'd like to exchange it for a replacement.
#
# **Would you like me to help you with anything else, or do you need assistance with the return process?**
#
# --------------------------------------------------
#
# Test Case 3: I have a Gaming Console Pro device , I want to check my warranty status, warranty serial number is MNO33333333.
# --------------------------------------------------
#
# Tool #1: LambdaUsingSDK___check_warranty_status
# I've checked your warranty status for your Gaming Console Pro. Here's what I found:
#
# ## **Warranty Status - Gaming Console Pro**
#
# | Detail | Information |
# |--------|-------------|
# | **Serial Number** | MNO33333333 |
# | **Product** | Gaming Console Pro |
# | **Purchase Date** | November 25, 2023 |
# | **Warranty End Date** | November 25, 2024 |
# | **Warranty Type** | Gaming Warranty |
# | **Status** | ❌ **EXPIRED** |
# | **Expired** | 425 days ago |
#
# ## **Coverage Details (Original Warranty Included):**
# - Controller issues
# - Overheating protection
# - Hard drive replacement
#
# ---
#
# ## **Next Steps:**
#
# Since your warranty has expired, here are your options:
#
# 1. **Extended Warranty** - Extended warranty options may be available for your device
# 2. **Paid Repair Service** - You can contact our support team for repair service pricing
# 3. **Out-of-Warranty Support** - We may still be able to assist with troubleshooting
#
# **Is there a specific issue with your Gaming Console Pro that you'd like help with?** I can provide technical support or connect you with our repair service team for pricing information.
#
# Is there anything else I can assist you with today?I've checked your warranty status for your Gaming Console Pro. Here's what I found:
#
# ## **Warranty Status - Gaming Console Pro**
#
# | Detail | Information |
# |--------|-------------|
# | **Serial Number** | MNO33333333 |
# | **Product** | Gaming Console Pro |
# | **Purchase Date** | November 25, 2023 |
# | **Warranty End Date** | November 25, 2024 |
# | **Warranty Type** | Gaming Warranty |
# | **Status** | ❌ **EXPIRED** |
# | **Expired** | 425 days ago |
#
# ## **Coverage Details (Original Warranty Included):**
# - Controller issues
# - Overheating protection
# - Hard drive replacement
#
# ---
#
# ## **Next Steps:**
#
# Since your warranty has expired, here are your options:
#
# 1. **Extended Warranty** - Extended warranty options may be available for your device
# 2. **Paid Repair Service** - You can contact our support team for repair service pricing
# 3. **Out-of-Warranty Support** - We may still be able to assist with troubleshooting
#
# **Is there a specific issue with your Gaming Console Pro that you'd like help with?** I can provide technical support or connect you with our repair service team for pricing information.
#
# Is there anything else I can assist you with today?
#
# --------------------------------------------------
#
# Test Case 4: What are the warranty support guidelines?
# --------------------------------------------------
#
#
# I'd be happy to help you with warranty support guidelines! Let me search for the most current and comprehensive warranty support information for you.
# Tool #1: LambdaUsingSDK___web_search
#
# Tool #2: get_product_info
# Let me provide you with comprehensive warranty support guidelines based on our standard policies:
#
# ## **General Warranty Support Guidelines**
#
# ### **1. Warranty Coverage Types**
# - **Standard Manufacturer Warranty**: Typically 1 year from purchase date
# - **Extended Warranty**: Optional coverage beyond the standard period
# - **Gaming Warranty** (for gaming devices): Covers controller issues, overheating protection, and hardware replacements
#
# ### **2. What's Typically Covered**
# ✅ Manufacturing defects
# ✅ Hardware failures
# ✅ Component malfunctions
# ✅ Overheating issues (device-specific)
# ✅ Hard drive/storage failures
# ✅ Controller/accessory issues
#
# ### **3. What's NOT Covered**
# ❌ Physical damage from drops or accidents
# ❌ Water damage or liquid exposure
# ❌ Normal wear and tear
# ❌ Misuse or improper handling
# ❌ Unauthorized repairs or modifications
# ❌ Cosmetic damage
#
# ### **4. Warranty Claim Process**
# 1. **Verify Warranty Status** - Check your serial number (like you did today)
# 2. **Contact Support** - Reach out with your serial number and issue description
# 3. **Provide Documentation** - Original proof of purchase and warranty card
# 4. **Device Inspection** - Send device for evaluation if needed
# 5. **Repair/Replacement** - Device is repaired or replaced if covered
# 6. **Return Shipping** - Free return shipping provided
#
# ### **5. Warranty Duration**
# - **Standard Warranty**: 1 year from purchase date
# - **Extended Warranty**: Available for additional years (varies by product)
# - **Expired Warranty**: Out-of-warranty repairs available at standard service rates
#
# ### **6. Important Notes**
# - Device must be in original or good condition (no physical damage)
# - Factory reset may be required before return
# - Warranty is non-transferable unless specified
# - Keep your serial number and proof of purchase safe
#
# ---
#
# **For your Gaming Console Pro (Serial: MNO33333333):**
# Since your warranty expired on November 25, 2024, you would need to pay for repair services. However, we may have extended warranty options available.
#
# **Would you like me to:**
# - Help you with repair service pricing?
# - Provide information about extended warranty options?
# - Assist with any other warranty-related questions?Let me provide you with comprehensive warranty support guidelines based on our standard policies:
#
# ## **General Warranty Support Guidelines**
#
# ### **1. Warranty Coverage Types**
# - **Standard Manufacturer Warranty**: Typically 1 year from purchase date
# - **Extended Warranty**: Optional coverage beyond the standard period
# - **Gaming Warranty** (for gaming devices): Covers controller issues, overheating protection, and hardware replacements
#
# ### **2. What's Typically Covered**
# ✅ Manufacturing defects
# ✅ Hardware failures
# ✅ Component malfunctions
# ✅ Overheating issues (device-specific)
# ✅ Hard drive/storage failures
# ✅ Controller/accessory issues
#
# ### **3. What's NOT Covered**
# ❌ Physical damage from drops or accidents
# ❌ Water damage or liquid exposure
# ❌ Normal wear and tear
# ❌ Misuse or improper handling
# ❌ Unauthorized repairs or modifications
# ❌ Cosmetic damage
#
# ### **4. Warranty Claim Process**
# 1. **Verify Warranty Status** - Check your serial number (like you did today)
# 2. **Contact Support** - Reach out with your serial number and issue description
# 3. **Provide Documentation** - Original proof of purchase and warranty card
# 4. **Device Inspection** - Send device for evaluation if needed
# 5. **Repair/Replacement** - Device is repaired or replaced if covered
# 6. **Return Shipping** - Free return shipping provided
#
# ### **5. Warranty Duration**
# - **Standard Warranty**: 1 year from purchase date
# - **Extended Warranty**: Available for additional years (varies by product)
# - **Expired Warranty**: Out-of-warranty repairs available at standard service rates
#
# ### **6. Important Notes**
# - Device must be in original or good condition (no physical damage)
# - Factory reset may be required before return
# - Warranty is non-transferable unless specified
# - Keep your serial number and proof of purchase safe
#
# ---
#
# **For your Gaming Console Pro (Serial: MNO33333333):**
# Since your warranty expired on November 25, 2024, you would need to pay for repair services. However, we may have extended warranty options available.
#
# **Would you like me to:**
# - Help you with repair service pricing?
# - Provide information about extended warranty options?
# - Assist with any other warranty-related questions?
#
# --------------------------------------------------
#
# Test Case 5: How can I fix Lenovo Thinkpad with a blue screen
# --------------------------------------------------
#
#
# I'm sorry to hear you're experiencing a blue screen issue with your Lenovo ThinkPad! That's definitely frustrating. Let me help you troubleshoot this problem.
# Tool #1: get_technical_support
#
# Tool #2: LambdaUsingSDK___web_search
# Successfully retrieved KB ID: 9DN5FS1RMZ
# Great! I found comprehensive troubleshooting information for your Lenovo ThinkPad blue screen issue. Here's a step-by-step guide to help you fix it:
#
# ## **Lenovo ThinkPad Blue Screen (BSOD) Troubleshooting Guide**
#
# ### **Immediate Steps (If Stuck on Blue Screen)**
# 1. **Try pressing the Windows button** - May wake the system
# 2. **Press Ctrl + Alt + Delete** - Attempt to access task manager or restart
# 3. **Force restart** - Hold power button for 10 seconds if unresponsive
#
# ---
#
# ### **Step 1: Boot in Safe Mode**
# If Windows won't start normally:
# 1. Restart your ThinkPad
# 2. Press **F8** repeatedly during startup
# 3. Select **Safe Mode with Networking**
# 4. This loads only essential drivers and files
#
# ---
#
# ### **Step 2: Remove External Hardware**
# Blue screens can be caused by hardware conflicts:
# - Disconnect external monitors, keyboards, printers
# - Remove USB devices and external storage
# - Unplug any secondary peripherals
# - Then try restarting
#
# ---
#
# ### **Step 3: Check for Windows Updates**
# 1. Go to **Settings > Update & Security**
# 2. Click **Check for updates**
# 3. Install any pending updates
# 4. Restart your system
#
# ---
#
# ### **Step 4: System Restore**
# If the issue started recently:
# 1. Go to **Settings > System > About**
# 2. Click **System restore**
# 3. Choose a restore point from before the issue began
# 4. Follow the prompts to restore
#
# ---
#
# ### **Step 5: Reset BIOS Settings**
# Corrupted BIOS can cause blue screens:
# 1. Restart and press **F1** or **F2** during startup (ThinkPad BIOS entry)
# 2. Look for **Reset to Default** or **Load Setup Defaults**
# 3. Save and exit
# 4. Restart your system
#
# ---
#
# ### **Step 6: Perform Startup Repair**
# 1. Boot from Windows installation media
# 2. Select **Repair your computer**
# 3. Choose **Troubleshoot > Advanced options > Startup Repair**
# 4. Let it run and restart
#
# ---
#
# ### **Step 7: Laptop Maintenance Check**
# Based on our maintenance guidelines:
# - **Check for overheating** - Excessive heat can cause crashes
# - **Clean vents and fans** - Use compressed air
# - **Update all drivers** - Especially chipset and graphics drivers
# - **Check hard drive health** - Run disk diagnostics
# - **Keep 15-20% disk space free** - Low storage causes issues
#
# ---
#
# ### **If Problem Persists:**
# - **Perform a clean Windows installation** - Last resort option
# - **Contact Lenovo Support** - May indicate hardware failure
# - **Check warranty status** - If covered, get professional repair
#
# ---
#
# **Quick Question:**
# - Is this a recurring blue screen, or did it just start?
# - Do you see an error code on the blue screen?
# - When does it occur (startup, during use, specific applications)?
#
# This information will help me provide more targeted solutions. Would you like me to help with anything else?Great! I found comprehensive troubleshooting information for your Lenovo ThinkPad blue screen issue. Here's a step-by-step guide to help you fix it:
#
# ## **Lenovo ThinkPad Blue Screen (BSOD) Troubleshooting Guide**
#
# ### **Immediate Steps (If Stuck on Blue Screen)**
# 1. **Try pressing the Windows button** - May wake the system
# 2. **Press Ctrl + Alt + Delete** - Attempt to access task manager or restart
# 3. **Force restart** - Hold power button for 10 seconds if unresponsive
#
# ---
#
# ### **Step 1: Boot in Safe Mode**
# If Windows won't start normally:
# 1. Restart your ThinkPad
# 2. Press **F8** repeatedly during startup
# 3. Select **Safe Mode with Networking**
# 4. This loads only essential drivers and files
#
# ---
#
# ### **Step 2: Remove External Hardware**
# Blue screens can be caused by hardware conflicts:
# - Disconnect external monitors, keyboards, printers
# - Remove USB devices and external storage
# - Unplug any secondary peripherals
# - Then try restarting
#
# ---
#
# ### **Step 3: Check for Windows Updates**
# 1. Go to **Settings > Update & Security**
# 2. Click **Check for updates**
# 3. Install any pending updates
# 4. Restart your system
#
# ---
#
# ### **Step 4: System Restore**
# If the issue started recently:
# 1. Go to **Settings > System > About**
# 2. Click **System restore**
# 3. Choose a restore point from before the issue began
# 4. Follow the prompts to restore
#
# ---
#
# ### **Step 5: Reset BIOS Settings**
# Corrupted BIOS can cause blue screens:
# 1. Restart and press **F1** or **F2** during startup (ThinkPad BIOS entry)
# 2. Look for **Reset to Default** or **Load Setup Defaults**
# 3. Save and exit
# 4. Restart your system
#
# ---
#
# ### **Step 6: Perform Startup Repair**
# 1. Boot from Windows installation media
# 2. Select **Repair your computer**
# 3. Choose **Troubleshoot > Advanced options > Startup Repair**
# 4. Let it run and restart
#
# ---
#
# ### **Step 7: Laptop Maintenance Check**
# Based on our maintenance guidelines:
# - **Check for overheating** - Excessive heat can cause crashes
# - **Clean vents and fans** - Use compressed air
# - **Update all drivers** - Especially chipset and graphics drivers
# - **Check hard drive health** - Run disk diagnostics
# - **Keep 15-20% disk space free** - Low storage causes issues
#
# ---
#
# ### **If Problem Persists:**
# - **Perform a clean Windows installation** - Last resort option
# - **Contact Lenovo Support** - May indicate hardware failure
# - **Check warranty status** - If covered, get professional repair
#
# ---
#
# **Quick Question:**
# - Is this a recurring blue screen, or did it just start?
# - Do you see an error code on the blue screen?
# - When does it occur (startup, during use, specific applications)?
#
# This information will help me provide more targeted solutions. Would you like me to help with anything else?
#
# --------------------------------------------------
#
# Test Case 6: Tell me detailed information about the technical documentation on installing a new CPU
# --------------------------------------------------
#
#
# Let me search for detailed technical documentation on CPU installation for you.
# Tool #1: LambdaUsingSDK___web_search
#
# Tool #2: get_technical_support
# Successfully retrieved KB ID: 9DN5FS1RMZ
# Let me provide you with comprehensive technical documentation on CPU installation. Based on the search results and technical support information, here's a detailed guide:
#
# ## **CPU Installation - Detailed Technical Documentation**
#
# ### **Important Disclaimer**
# ⚠️ **CPU installation varies significantly by device type:**
# - **Desktop Computers** - More accessible, user-serviceable
# - **Laptops** - Often requires professional service (soldered or proprietary)
# - **Servers** - Specialized procedures required
#
# ---
#
# ### **Pre-Installation Requirements**
#
# #### **Tools & Materials Needed:**
# - Anti-static wrist strap (ESD protection)
# - Thermal paste (if replacing thermal interface)
# - Screwdrivers (Phillips and possibly Torx)
# - Flashlight or headlamp
# - Clean, lint-free cloth
# - Isopropyl alcohol (90%+ concentration)
# - Documentation for your specific device
#
# #### **Safety Precautions:**
# 1. **Power Down Completely** - Shut down and unplug from power
# 2. **Wait 5-10 minutes** - Allow system to cool
# 3. **Ground Yourself** - Wear anti-static wrist strap connected to case
# 4. **Avoid Static** - Work on non-carpeted surface
# 5. **Remove Jewelry** - Metal can cause shorts
#
# ---
#
# ### **General CPU Installation Steps (Desktop)**
#
# #### **Step 1: Access the Motherboard**
# 1. Remove side panel of computer case
# 2. Locate the CPU socket (usually near RAM slots)
# 3. Document cable positions with photos for reassembly
#
# #### **Step 2: Remove Old CPU (if applicable)**
# 1. Locate CPU retention mechanism (lever, latch, or screws)
# 2. Carefully release the retention mechanism
# 3. Gently lift CPU straight up - **DO NOT twist or force**
# 4. Place old CPU in anti-static bag
#
# #### **Step 3: Prepare Socket**
# 1. Clean socket contacts with compressed air
# 2. Inspect for bent pins or damage
# 3. Verify socket type matches new CPU
#
# #### **Step 4: Install New CPU**
# 1. **Align the CPU** - Match notches/markers on CPU and socket
# 2. **Gentle Placement** - Lower CPU straight down into socket
# 3. **Secure Retention** - Engage latch or fasteners
# 4. **Verify Seating** - CPU should sit flush with no gaps
#
# #### **Step 5: Apply Thermal Paste**
# 1. Clean old thermal paste with isopropyl alcohol
# 2. Apply small pea-sized amount to CPU center
# 3. Use thermal paste spreader or plastic card
# 4. Create thin, even layer (0.5-1mm)
#
# #### **Step 6: Install Cooler**
# 1. Follow cooler manufacturer's instructions
# 2. Ensure even pressure across CPU
# 3. Secure all mounting brackets
# 4. Connect cooler power cable to motherboard
#
# #### **Step 7: Reassemble & Test**
# 1. Reconnect all cables carefully
# 2. Replace side panel
# 3. Plug in power and boot system
# 4. Monitor temperatures during startup
# 5. Check BIOS for CPU recognition
#
# ---
#
# ### **Important Considerations**
#
# #### **Laptop CPU Installation:**
# ⚠️ **Most modern laptops have:**
# - **Soldered CPUs** - Cannot be replaced by users
# - **Proprietary designs** - Requires manufacturer service
# - **Complex disassembly** - Risk of damage
#
# **Recommendation:** Contact manufacturer or professional service for laptop CPU replacement
#
# #### **Thermal Management:**
# - Monitor CPU temperatures after installation
# - Ideal operating range: 30-70°C (idle to load)
# - Excessive heat indicates poor thermal contact
# - May need to reseat cooler if temps are high
#
# #### **BIOS/Firmware:**
# - System may require BIOS update for new CPU compatibility
# - Check motherboard manufacturer website
# - Update BIOS before installing new CPU if needed
#
# ---
#
# ### **Troubleshooting Common Issues**
#
# | Issue | Solution |
# |-------|----------|
# | **System won't boot** | Reseat CPU, check power connections |
# | **High temperatures** | Reapply thermal paste, check cooler mounting |
# | **CPU not recognized** | Update BIOS, verify socket compatibility |
# | **Bent pins** | For AMD: Carefully straighten with tweezers; For Intel: Contact support |
# | **Cooler won't fit** | Verify cooler compatibility with socket type |
#
# ---
#
# ### **Warranty & Safety Notes**
# - ⚠️ **Opening your device may void warranty** - Check warranty terms first
# - 🛡️ **Static electricity can damage components** - Always use ESD protection
# - 📋 **Keep documentation** - Save all manuals and receipts
# - 🔧 **Professional service available** - Consider professional installation if uncertain
#
# ---
#
# ### **For Your Specific Device:**
#
# **To provide more detailed instructions, I need to know:**
# 1. **Device type** - Desktop, laptop, or server?
# 2. **Motherboard model** - Check documentation or BIOS
# 3. **Current CPU** - What are you replacing?
# 4. **New CPU** - What model are you installing?
# 5. **Socket type** - Intel LGA1700, AMD AM5, etc.?
#
# **Would you like me to:**
# - Search for specific CPU installation guides for your device?
# - Help you find your motherboard specifications?
# - Provide technical support for a specific installation issue?
# - Check warranty implications for your device?
#
# Let me know the details, and I can provide more targeted technical documentation!Let me provide you with comprehensive technical documentation on CPU installation. Based on the search results and technical support information, here's a detailed guide:
#
# ## **CPU Installation - Detailed Technical Documentation**
#
# ### **Important Disclaimer**
# ⚠️ **CPU installation varies significantly by device type:**
# - **Desktop Computers** - More accessible, user-serviceable
# - **Laptops** - Often requires professional service (soldered or proprietary)
# - **Servers** - Specialized procedures required
#
# ---
#
# ### **Pre-Installation Requirements**
#
# #### **Tools & Materials Needed:**
# - Anti-static wrist strap (ESD protection)
# - Thermal paste (if replacing thermal interface)
# - Screwdrivers (Phillips and possibly Torx)
# - Flashlight or headlamp
# - Clean, lint-free cloth
# - Isopropyl alcohol (90%+ concentration)
# - Documentation for your specific device
#
# #### **Safety Precautions:**
# 1. **Power Down Completely** - Shut down and unplug from power
# 2. **Wait 5-10 minutes** - Allow system to cool
# 3. **Ground Yourself** - Wear anti-static wrist strap connected to case
# 4. **Avoid Static** - Work on non-carpeted surface
# 5. **Remove Jewelry** - Metal can cause shorts
#
# ---
#
# ### **General CPU Installation Steps (Desktop)**
#
# #### **Step 1: Access the Motherboard**
# 1. Remove side panel of computer case
# 2. Locate the CPU socket (usually near RAM slots)
# 3. Document cable positions with photos for reassembly
#
# #### **Step 2: Remove Old CPU (if applicable)**
# 1. Locate CPU retention mechanism (lever, latch, or screws)
# 2. Carefully release the retention mechanism
# 3. Gently lift CPU straight up - **DO NOT twist or force**
# 4. Place old CPU in anti-static bag
#
# #### **Step 3: Prepare Socket**
# 1. Clean socket contacts with compressed air
# 2. Inspect for bent pins or damage
# 3. Verify socket type matches new CPU
#
# #### **Step 4: Install New CPU**
# 1. **Align the CPU** - Match notches/markers on CPU and socket
# 2. **Gentle Placement** - Lower CPU straight down into socket
# 3. **Secure Retention** - Engage latch or fasteners
# 4. **Verify Seating** - CPU should sit flush with no gaps
#
# #### **Step 5: Apply Thermal Paste**
# 1. Clean old thermal paste with isopropyl alcohol
# 2. Apply small pea-sized amount to CPU center
# 3. Use thermal paste spreader or plastic card
# 4. Create thin, even layer (0.5-1mm)
#
# #### **Step 6: Install Cooler**
# 1. Follow cooler manufacturer's instructions
# 2. Ensure even pressure across CPU
# 3. Secure all mounting brackets
# 4. Connect cooler power cable to motherboard
#
# #### **Step 7: Reassemble & Test**
# 1. Reconnect all cables carefully
# 2. Replace side panel
# 3. Plug in power and boot system
# 4. Monitor temperatures during startup
# 5. Check BIOS for CPU recognition
#
# ---
#
# ### **Important Considerations**
#
# #### **Laptop CPU Installation:**
# ⚠️ **Most modern laptops have:**
# - **Soldered CPUs** - Cannot be replaced by users
# - **Proprietary designs** - Requires manufacturer service
# - **Complex disassembly** - Risk of damage
#
# **Recommendation:** Contact manufacturer or professional service for laptop CPU replacement
#
# #### **Thermal Management:**
# - Monitor CPU temperatures after installation
# - Ideal operating range: 30-70°C (idle to load)
# - Excessive heat indicates poor thermal contact
# - May need to reseat cooler if temps are high
#
# #### **BIOS/Firmware:**
# - System may require BIOS update for new CPU compatibility
# - Check motherboard manufacturer website
# - Update BIOS before installing new CPU if needed
#
# ---
#
# ### **Troubleshooting Common Issues**
#
# | Issue | Solution |
# |-------|----------|
# | **System won't boot** | Reseat CPU, check power connections |
# | **High temperatures** | Reapply thermal paste, check cooler mounting |
# | **CPU not recognized** | Update BIOS, verify socket compatibility |
# | **Bent pins** | For AMD: Carefully straighten with tweezers; For Intel: Contact support |
# | **Cooler won't fit** | Verify cooler compatibility with socket type |
#
# ---
#
# ### **Warranty & Safety Notes**
# - ⚠️ **Opening your device may void warranty** - Check warranty terms first
# - 🛡️ **Static electricity can damage components** - Always use ESD protection
# - 📋 **Keep documentation** - Save all manuals and receipts
# - 🔧 **Professional service available** - Consider professional installation if uncertain
#
# ---
#
# ### **For Your Specific Device:**
#
# **To provide more detailed instructions, I need to know:**
# 1. **Device type** - Desktop, laptop, or server?
# 2. **Motherboard model** - Check documentation or BIOS
# 3. **Current CPU** - What are you replacing?
# 4. **New CPU** - What model are you installing?
# 5. **Socket type** - Intel LGA1700, AMD AM5, etc.?
#
# **Would you like me to:**
# - Search for specific CPU installation guides for your device?
# - Help you find your motherboard specifications?
# - Provide technical support for a specific installation issue?
# - Check warranty implications for your device?
#
# Let me know the details, and I can provide more targeted technical documentation!
#
# --------------------------------------------------
# \n✅ Basic testing completed!

# %% [markdown]
# ### Congratulations! 🎉
#
#
# You have successfully completed Lab 3: Securely connect tools to your Agent with AgentCore Gateway
#
# What You Accomplished:
#
# ##### Tool Centralization & Reusability:
#
# - Migrated web search from local tool to centralized AgentCore Gateway
# - Integrated existing enterprise Lambda functions (warranty check, customer profile)
# - Created a shared tool infrastructure that multiple agent types can access
#
# ##### Enterprise-Grade Security:
#
# - Implemented JWT-based authentication with Cognito integration
# - Configured secure inbound authorization for gateway access
# - Established identity-based access control for tool usage
#
# ##### Scalable Architecture Foundation:
#
# - Built reusable tools that serve multiple use cases (customer support, sales, returns processing)
# - Eliminated code duplication across different agents
# - Created centralized management for tool updates and maintenance
#
# ##### Current Limitations (We'll fix these next!):
#
# - **Local Development Environment** - Still running on your laptop, not production-ready
# - **Limited Observability** - No comprehensive monitoring of agent behavior and performance
# - **Manual Scaling** - Cannot automatically handle increased load or multiple concurrent users
#
# ##### Next Up: Lab 4 - Deploying to Production with AgentCore Runtime
#
# In Lab 4, you'll transform your prototype into a production-ready system with:
#
# - AgentCore Runtime for scalable agent deployment
# - Comprehensive observability with metrics, logging, and tracing
# - Auto-scaling capabilities to handle real-world traffic
#
# ### Resources
# - [Amazon Bedrock Agent Core Gateway](https://docs.aws.amazon.com/bedrock-agentcore/latest/devguide/gateway.html)
# - [Strands Agents Documentation](https://github.com/strands-agents/sdk-python)
# - [Official Customer Support Sample](https://github.com/awslabs/amazon-bedrock-agentcore-samples/tree/main/02-use-cases/customer-support-assistant)
